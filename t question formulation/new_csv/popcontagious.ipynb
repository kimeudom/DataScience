# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0=pd.read_csv(r"D:\github\DataScience\t question formulation\new_csv\Population data.csv")
print(df0.columns)
df0.drop(['County Code'], axis =1,inplace=True)
# Out:
# Index(['County Code', 'Counties', 'Census'], dtype='object')

# %%
df1=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\prevalence\HIV_County_Total_Cases.csv")
df2=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\prevalence\Mal_County_Total_Cases.csv")
df3=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\prevalence\TB_County_Total_Cases.csv")
df1.drop(['County_code'], axis =1,inplace=True)
df2.drop(['County_code'], axis =1,inplace=True)
df3.drop(['County_code'], axis =1,inplace=True)
H = df1.Prevalence
M = df2.Prevalence
T = df3.Prevalence
sum=H+T+M
L = [H,M,T]

# %%
frames = [df0]
frame2 = [df1,df2,df3]
df=pd.concat(frames, ignore_index=True)
df2=pd.concat(frame2, ignore_index=True)

# %%
print(df.columns)
print(df2.columns)
# Out:
# Index(['Counties', 'Census'], dtype='object')
# Index(['County', 'Prevalence'], dtype='object')

# %%
plt.rcParams['figure.figsize']=(15,15)
df.plot.bar(x="Counties",y="Census")
df2.plot.bar(x="County",y="Prevalence")
# Out:
# <AxesSubplot:xlabel='County'>
