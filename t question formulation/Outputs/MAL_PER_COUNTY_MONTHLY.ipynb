# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\Counties.csv")
#df0.drop(['County_code'], axis =1,inplace=True)

# %%
df1=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\Mal_Spread_monthly.csv")

# %%
frames = [df0,df1,]
df=pd.concat(frames, ignore_index=True)

# %%
print(df.columns)
# Out:
# Index(['County_code', 'County', 'Data', 'Jan', 'Feb', 'Mar', 'Apr', 'May',
#        'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
print(df1)
# Out:
#                     County                                     Data    Jan  \
# 0           Bungoma County  Confirmed Malaria (only Positive cases)  20606
# 1   Elgeyo Marakwet County  Confirmed Malaria (only Positive cases)    861
# 2              Embu County  Confirmed Malaria (only Positive cases)     46
# 3           Kajiado County  Confirmed Malaria (only Positive cases)    617
# 4          Kakamega County  Confirmed Malaria (only Positive cases)  22001
# 5           Kericho County  Confirmed Malaria (only Positive cases)   1015
# 6            Kilifi County  Confirmed Malaria (only Positive cases)   7675
# 7             Kisii County  Confirmed Malaria (only Positive cases)   1835
# 8             Kwale County  Confirmed Malaria (only Positive cases)   3089
# 9          Laikipia County  Confirmed Malaria (only Positive cases)    116
# 10             Lamu County  Confirmed Malaria (only Positive cases)     40
# 11         Machakos County  Confirmed Malaria (only Positive cases)    405
# 12          Mandera County  Confirmed Malaria (only Positive cases)     43
# 13         Marsabit County  Confirmed Malaria (only Positive cases)    198
# 14          Nairobi County  Confirmed Malaria (only Positive cases)   4071
# 15           Nakuru County  Confirmed Malaria (only Positive cases)   1722
# 16            Nyeri County  Confirmed Malaria (only Positive cases)     61
# 17       Tana River County  Confirmed Malaria (only Positive cases)    723
# 18          Turkana County  Confirmed Malaria (only Positive cases)  18273
# 19            Wajir County  Confirmed Malaria (only Positive cases)     58
#
#       Feb    Mar    Apr    May     Jun    Jul    Aug    Sep    Oct    Nov  \
# 0   32959  34511  33912  48557   64205  43083  43368  41521  22840  20397
# 1     933   1123    789   1011    1236    962   1450   1091    778    782
# 2      61    130     75    140      49     57     75     68     27     32
# 3     419    534    447    434     596    776    486    280    464    291
# 4   47698  68503  66059  87051  113827  83404  68752  63114  37842  36686
# 5    1614   2187   1737   2374    3448   2598   2540   2189   1564   1920
# 6    6476  10426   5581   7809    7137   8138   6342   6436   7197   8001
# 7    2475   4523   3362   4855    5164   4302   4276   4585   3582   3817
# 8   17349  11617   6768  13442   14018  33297  14833  10828  10011   9453
# 9      67     69     36     56     421     55     56    107     24     39
# 10     28     52     10     23      18     24     17     12     28     14
# 11    277    203    203    183     206    376    302     98    255   1377
# 12     40     60     33     55     157     91     50     28     48     69
# 13    164    103    131    152     131    154    159    140     64    146
# 14   2658   3109   1912   2511    3003   3351   2546   2167   2227   1790
# 15   1402   1384    968   1176    1493   1482   1584   1593   1204   1397
# 16     24     31     42     47      36     27     27     31     16     12
# 17    686    508    360    440     460    450    469    339    345    356
# 18  14474  11701   9160  16752   28993  32231  63955  37237  32752  22284
# 19     31     84     12     29      43     65     45    139     56     33
#
#       Dec
# 0   24748
# 1    1119
# 2      50
# 3     340
# 4   38575
# 5    2430
# 6    7285
# 7    5255
# 8    8857
# 9      15
# 10     12
# 11     97
# 12     12
# 13    128
# 14   2144
# 15   1395
# 16     32
# 17    426
# 18  13420
# 19     14

# %%
print(df.columns)
# Out:
# Index(['County_code', 'County', 'Data', 'Jan', 'Feb', 'Mar', 'Apr', 'May',
#        'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
df2=df1[df1["County"]=="Kisumu County"]
print(df2)
# Out:
#              County                                     Data  Jan  Feb  Mar  \
# 13  Marsabit County  Confirmed Malaria (only Positive cases)  198  164  103
#
#     Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# 13  131  152  131  154  159  140   64  146  128

# %%
def plot(y, format="-r", lineLabel="",xLabel="Months",yLabel="Number of Cases"):
     ax.plot(y, format, label=lineLabel)
     ax.legend(loc=2)
     ax.set_xlabel(xLabel)
     ax.set_ylabel(yLabel)
     #ax.set_xticks(x)

# %%
plt.rcParams['figure.figsize']=(15,15)
fig, ax=plt.subplots()
plot((df2.Jan,df2.Feb,df2.Mar,df2.Apr,df2.May,df2.Jun,df2.Jul,df2.Aug,df2.Sep,df2.Oct,df2.Nov,df2.Dec),"-gx",lineLabel="Cases", xLabel="Months", yLabel="Cases in Month")
plt.xticks(rotation=45, ha='right')
plt.show() 
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]
