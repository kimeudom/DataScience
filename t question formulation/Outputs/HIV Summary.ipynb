# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0=pd.read_csv(r"/home/dom/Data_Science/t question formulation/Outputs/Counties.csv")

#df0.drop(['County_code'], axis =1,inplace=True)

# %%
df1=pd.read_csv(r"/home/dom/Data_Science/t question formulation/Outputs/HIV_monthly.csv")

# %%
frames = [df0,df1,]
df=pd.concat(frames, ignore_index=True)

# %%
print(df.columns)
# Out:
# Index(['County_code', 'County', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
#        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
print(df.columns)
# Out:
# Index(['County_code', 'County', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
#        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
print(df1)
# Out:
#                County  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  \
# 0      Baringo County   41   49   34   47   51   59   46   34   37   71   48
# 1      Bungoma County  257  270  225  260  295  326  288  279  275  265  194
# 2      Kajiado County  115  143  164  159  185  181  148  158  198  161  162
# 3      Kericho County  107  143   98  121  156  104  108  114  112  114  143
# 4       Kiambu County  374  371  313  376  430  465  408  387  345  354  364
# 5       Kilifi County  267  230  199  206  247  281  218  219  260  243  270
# 6    Kirinyaga County   65   64   73   60   62  102   84   83   57   64   54
# 7       Kisumu County  740  749  731  797  878  853  729  766  759  712  593
# 8        Kitui County  168  193  140  171  201  163  140  158  159  176  181
# 9        Kwale County   48   98   71   88  110  113  107   75  100   93  100
# 10     Mandera County    4   10    0    3    2    6    2    6    7    3    6
# ...

# %%
counties = df1.County
df2=df1[df1["County"]== counties]
print(df2)
# Out:
#                County  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  \
# 0      Baringo County   41   49   34   47   51   59   46   34   37   71   48
# 1      Bungoma County  257  270  225  260  295  326  288  279  275  265  194
# 2      Kajiado County  115  143  164  159  185  181  148  158  198  161  162
# 3      Kericho County  107  143   98  121  156  104  108  114  112  114  143
# 4       Kiambu County  374  371  313  376  430  465  408  387  345  354  364
# 5       Kilifi County  267  230  199  206  247  281  218  219  260  243  270
# 6    Kirinyaga County   65   64   73   60   62  102   84   83   57   64   54
# 7       Kisumu County  740  749  731  797  878  853  729  766  759  712  593
# 8        Kitui County  168  193  140  171  201  163  140  158  159  176  181
# 9        Kwale County   48   98   71   88  110  113  107   75  100   93  100
# 10     Mandera County    4   10    0    3    2    6    2    6    7    3    6
# ...

# %%
def plot(y, format="-r", lineLabel="",xLabel="Months",yLabel="Number of Cases"):
     ax.plot(y, format, label=lineLabel)
     ax.legend(loc=2)
     ax.set_title("Line Chart Summary of HIV Cases in 2021", color = '0.7' )
     ax.set_autoscalex_on = True
     ax.set_xlabel(xLabel)
     ax.set_ylabel(yLabel)
     #ax.set_xticks(x)

# %%
plt.rcParams['figure.figsize']=(15,15)
fig, ax=plt.subplots()
plot((df2.Jan,df2.Feb,df2.Mar,df2.Apr,df2.May,df2.Jun,df2.Jul,df2.Aug,df2.Sep,df2.Oct,df2.Nov,df2.Dec),"-gx", xLabel="Months", yLabel="Cases in Month")
plt.xticks(rotation=45, ha='right')
plt.show() 
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]
