# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\Counties.csv")
df0.drop(['County_code'], axis =1,inplace=True)

# %%
df1=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\prevalence\HIV_County_Total_Cases.csv")

# %%
frames = [df0,df1,]
df=pd.concat(frames, ignore_index=True)

# %%
print(df.columns)
# Out:
# Index(['County', 'County_code', 'Prevalence'], dtype='object')

# %%
df2=df1[df1["County"]=="Nairobi County"]
print(df2)
# Out:
# Empty DataFrame
# Columns: [County_code, County, Prevalence]
# Index: []

# %%
def plot(y, format="-r", lineLabel="",xLabel="",yLabel=""):
     ax.plot(y, format, label=lineLabel)
     ax.legend(loc=2)
     ax.set_xlabel(xLabel)
     ax.set_ylabel(yLabel)
     #ax.set_xticks(x)

# %%
plt.rcParams['figure.figsize']=(15,15)
fig, ax=plt.subplots()
plot((df2.Prevalence),"-gx",lineLabel="Cases", xLabel="Months", yLabel="Cases in Month")
plt.xticks(rotation=45, ha='right')
plt.show() 
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]
