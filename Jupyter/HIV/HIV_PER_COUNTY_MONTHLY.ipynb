# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\Counties.csv")

#df0.drop(['County_code'], axis =1,inplace=True)

# %%
df1=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\HIV_monthly.csv")

# %%
df2=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\Total contraceptives.csv")
df2.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5','Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10','Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14','Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18','Unnamed: 19', 'Unnamed: 20', 'total contraceptives used in one year'],axis=1)
# Out:
#                     County      Sum
# 0           Nairobi County  7656056
# 1            Migori County  5921752
# 2            Nakuru County  5290156
# 3            Kilifi County  4781461
# 4          Homa Bay County  4673331
# 5           Bungoma County  4468611
# 6             Kisii County  4266518
# 7          Kakamega County  3317150
# 8             Kitui County  2503615
# 9            Kiambu County  2253974
# 10          Nyamira County  2248250
# 11      Uasin Gishu County  1921605
# 12            Nandi County  1887286
# 13      Trans Nzoia County  1752974
# 14         Machakos County  1566843
# 15          Mombasa County  1488275
# 16            Bomet County  1433347
# 17       West Pokot County  1207243
# 18            Kwale County  1178530
# 19            Narok County  1099918
# 20     Taita Taveta County  1092677
# 21            Nyeri County  1048594
# 22          Turkana County   983589
# 23         Laikipia County   926529
# 24          Makueni County   902159
# 25             Meru County   889441
# 26             Embu County   884277
# 27           Kisumu County   734989
# 28          Kajiado County   709041
# 29    Tharaka Nithi County   504744
# 30        Kirinyaga County   479122
# 31          Kericho County   214175
# 32          Garissa County   201119
# 33         Marsabit County   196036
# 34          Muranga County   159716
# 35            Busia County   140109
# 36       Tana River County   136922
# 37             Lamu County    97069
# 38          Samburu County    93229
# 39            Wajir County    77732
# 40        Nyandarua County    54535
# 41          Mandera County    48832
# 42           Isiolo County    48617
# 43  Elgeyo Marakwet County    39748
# 44          Baringo County    23525
# 45            Siaya County    12296
# 46           Vihiga County     3855

# %%
#frames = [df0,df1]
#frame2= [df1,df2]
#df=pd.concat(frames, ignore_index=True)

# %% [markdown]
# ## SELECTING A COUNTY

# %%
df3=df1[df1["County"]== "Kitui County"]

# %%
def plot(y, format="-r", lineLabel="",xLabel="Months",yLabel="Number of Cases"):
     ax.plot(y, format, label=lineLabel)
     ax.legend(loc=2)
     ax.set_xlabel(xLabel)
     ax.set_ylabel(yLabel)
     #ax.set_xticks(x)

# %% [markdown]
# # GRAPHS SHOWNG NUMBER OF HIV CASES IN A SELECT MONTH

# %%
plt.rcParams['figure.figsize']=(15,15)
fig, ax=plt.subplots()
plot((df3.Jan,df3.Feb,df3.Mar,df3.Apr,df3.May,df3.Jun,df3.Jul,df3.Aug,df3.Sep,df3.Oct,df3.Nov,df3.Dec),"-gx",lineLabel="Cases", xLabel="Months", yLabel="Cases in Month")
plt.xticks(rotation=45, ha='right')
plt.show() 
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]

# %%
df4=df2[df2["County"]== "Baringo County"]
df4.drop(['Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5','Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10','Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14','Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18','Unnamed: 19', 'Unnamed: 20', 'total contraceptives used in one year'],axis=1)
# Out:
#             County    Sum
# 44  Baringo County  23525

# %% [markdown]
# # GRAPHS SHOWING CONTRACEPTIVE USE IN THE COUNTIES

# %%
plt.rcParams['figure.figsize']=(15,15)
df2.plot.bar(x="County",y="Sum")
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]
