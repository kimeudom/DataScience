# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df1=pd.read_csv(r"D:\github\DataScience\t question formulation\Outputs\prevalence\TB_County_Total_Cases.csv")
df1.drop(['County_code'], axis =1,inplace=True)

# %%
frames = [df1,]
df=pd.concat(frames, ignore_index=True)

# %%
print(df.columns)
# Out:
# Index(['County', 'Prevalence'], dtype='object')

# %%
df2=df1[df1["County"]=="Nairobi County"]
print(df2)
# Out:
#             County  Prevalence
# 12  Nairobi County          78
# 26  Nairobi County         105

# %% [markdown]
# # BAR GRAPH SHOWING NUMBER OF TB CASES IN ALL COUNTIES

# %%
plt.rcParams['figure.figsize']=(15,15)
df.plot.bar(x="County",y="Prevalence")
# Out:
# <AxesSubplot:xlabel='County'>
