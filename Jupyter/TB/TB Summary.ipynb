# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df0=pd.read_csv(r"/home/dom/Data_Science/t question formulation/Outputs/Counties.csv")
#df0.drop(['County_code'], axis =1,inplace=True)

# %%
df1=pd.read_csv(r"/home/dom/Data_Science/t question formulation/Outputs/TB_monthly.csv")

# %%
frames = [df0,df1,]
df=pd.concat(frames, ignore_index=True)

# %%
print(df.columns)
# Out:
# Index(['County_code', 'County', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
#        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
print(df1)
# Out:
#                   County  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  \
# 0         Bungoma County    0    7    4    0    0   12   11   14    8    9
# 1         Garissa County    3    0    1    0    0    1    1    3    2    0
# 2        Kakamega County    2    8    7   13    7   10    8   17    8    5
# 3          Kiambu County    5   18   18   14   17   12   10   14    0   11
# 4          Kisumu County    1    1    3    1    3    1    0    0    0    1
# 5           Kitui County   10   12   17    0    0    0    0    0    0    0
# 6         Mandera County   10    3   16    2    0    4    0    1    2   19
# 7        Marsabit County   16    9   12    8    9    9   10   10    7    9
# 8         Mombasa County    0    0    0   19    0    0    0    0    0   12
# 9         Nairobi County   18    7    1   31    0   13    9    8   23   59
# 10      Nyandarua County    0    0    0    0    3    0    2    1    5    0
# 11          Siaya County    0    0    3    0    1    2    0    0    1    1
# 12  Tharaka Nithi County    2   11    9    6    2   12    8   15   12    0
#
#     Nov  Dec
# 0     0    3
# 1     0    3
# 2     9    3
# 3     9   12
# 4     1    0
# 5     0    0
# 6    16   14
# 7     8    6
# 8    12    8
# 9    30   22
# 10    0    3
# 11    2    2
# 12    0    4

# %%
print(df.columns)
# Out:
# Index(['County_code', 'County', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun',
#        'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'],
#       dtype='object')

# %%
counties = df1.County
df2=df1[df1["County"]== counties]
print(df2)
# Out:
#                   County  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  \
# 0         Bungoma County    0    7    4    0    0   12   11   14    8    9
# 1         Garissa County    3    0    1    0    0    1    1    3    2    0
# 2        Kakamega County    2    8    7   13    7   10    8   17    8    5
# 3          Kiambu County    5   18   18   14   17   12   10   14    0   11
# 4          Kisumu County    1    1    3    1    3    1    0    0    0    1
# 5           Kitui County   10   12   17    0    0    0    0    0    0    0
# 6         Mandera County   10    3   16    2    0    4    0    1    2   19
# 7        Marsabit County   16    9   12    8    9    9   10   10    7    9
# 8         Mombasa County    0    0    0   19    0    0    0    0    0   12
# 9         Nairobi County   18    7    1   31    0   13    9    8   23   59
# 10      Nyandarua County    0    0    0    0    3    0    2    1    5    0
# 11          Siaya County    0    0    3    0    1    2    0    0    1    1
# 12  Tharaka Nithi County    2   11    9    6    2   12    8   15   12    0
#
#     Nov  Dec
# 0     0    3
# 1     0    3
# 2     9    3
# 3     9   12
# 4     1    0
# 5     0    0
# 6    16   14
# 7     8    6
# 8    12    8
# 9    30   22
# 10    0    3
# 11    2    2
# 12    0    4

# %%
def plot(y, format="-r", lineLabel="",xLabel="Months",yLabel="Number of Cases"):
     ax.plot(y, format, label=lineLabel)
     ax.legend(loc=2)
     ax.set_xlabel(xLabel)
     ax.set_ylabel(yLabel)
     #ax.set_xticks(x)

# %%
plt.rcParams['figure.figsize']=(15,15)
fig, ax=plt.subplots()
plot((df2.Jan,df2.Feb,df2.Mar,df2.Apr,df2.May,df2.Jun,df2.Jul,df2.Aug,df2.Sep,df2.Oct,df2.Nov,df2.Dec),"-gx",lineLabel="Cases", xLabel="Months", yLabel="Cases in Month")
plt.xticks(rotation=45, ha='right')
plt.show() 
plt.rcParams["figure.figsize"] = plt.rcParamsDefault["figure.figsize"]
